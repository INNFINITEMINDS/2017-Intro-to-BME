# %%
# %matplotlib inline
# %reset -f
#for jupyter notebook

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, LSTM
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
from matplotlib import pyplot
import numpy as np
from datetime import datetime
import pandas as pd
#import seaborn as sns


dataset="dataset3"
numepoch=300 #undefitted; should be 80
batchsize=180
dropoutratio=0.1
modelloss="mse"
modelmetrics=['mean_squared_error', 'mean_absolute_error'] #['accuracy','mse', 'mae', 'mape', 'cosine']
#activationfx='relu'

np.random.seed(7)

def println():
	print "----------------------------------------------------------------------------------------------"

def plot(metric):
	if metric in history.history.keys():
		pyplot.plot(history.history[metric])
		print metric
		pyplot.show()

def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[np.newaxis,:,:])[0,])
        #print predicted[-1]
        curr_frame = curr_frame[6:]
        curr_frame = np.append(curr_frame, [[predicted[-1][0]]],axis=0)
        curr_frame = np.append(curr_frame, [[predicted[-1][1]]],axis=0)
        curr_frame = np.append(curr_frame, [[predicted[-1][2]]],axis=0)
        curr_frame = np.append(curr_frame, [[predicted[-1][3]]],axis=0)
        curr_frame = np.append(curr_frame, [[predicted[-1][4]]],axis=0)
        curr_frame = np.append(curr_frame, [[predicted[-1][5]]],axis=0)
        
    return predicted

'''
Input format:
User_Throughput_DL,User_Throughput_UL,pmRrcConnMax
29.8132982033821,0.851054597224795,505
25.4978881524593,0.772183560582853,464
'''
datasetstr = np.loadtxt(dataset+".csv", delimiter=",", skiprows=0)
datasetfloat = datasetstr.astype(np.float)
allScaler = MinMaxScaler()

datasetscaled =  allScaler.fit_transform(datasetfloat[:,:])

seq_len=48
sequence_length = seq_len + 1
result = []
for index in range(len(datasetscaled) - sequence_length):
	temp=[]
	first=True
	for a in range(sequence_length):
		for x in range(len(datasetscaled[0])):
			temp.append(datasetscaled[index + a][x])
	result.append(temp)
dataset=np.array(result)

predictionsteps=1
t=-1-predictionsteps*5
testingslice = int(len(dataset)*0.8)
trainX = dataset[:testingslice,:t]
trainY = dataset[:testingslice,t:]
testX = dataset[testingslice:,:t]
testY = dataset[testingslice:,t:]
predictX=dataset[testingslice:,:t]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1)) 
print "Dataset loaded."

model = Sequential()
model.add(LSTM(
    input_dim=1,
    output_dim=24,
    return_sequences=True))
model.add(Dropout(dropoutratio))
model.add(LSTM(
    24,
    return_sequences=False))
model.add(Dropout(dropoutratio))
'''
model.add(Dense(
        output_dim=24))
model.add(Activation("relu"))
'''
model.add(Dense(
        output_dim=6))
model.add(Activation("relu"))

model.compile(loss=modelloss, optimizer="rmsprop", metrics=modelmetrics)
#model.compile(optimizer='adam',loss='mse', metrics=['accuracy','mse', 'mae', 'mape', 'cosine'])
print "Model compiled."

#history=model.fit(trainX, trainY, epochs=numepoch, batch_size=batchsize,verbose=0)
history=model.fit(trainX, trainY, epochs=numepoch, batch_size=batchsize,verbose=2) #validation_data=(testX,testY))
print "Model trained."
println()
plot( "acc")
plot("mean_squared_error")
plot("mean_absolute_error")
plot("val_acc")
plot("val_mean_squared_error")
plot("val_mean_absolute_error")
println()

print "\n"
print "Training metrics"
for i in modelmetrics:
    print("%s: %s" % (i, history.history[i][-1]))
print "\n"

'''
pyplot.plot(history.history['mean_squared_error'])
pyplot.plot(history.history['mean_absolute_error'])
pyplot.plot(history.history['mean_absolute_percentage_error'])
pyplot.plot(history.history['cosine_proximity'])
#https://machinelearningmastery.com/custom-metrics-deep-learning-keras-python/

->model.metrics_names
['loss',
 'acc',
 'mean_squared_error',
 'mean_absolute_error',
 'mean_absolute_percentage_error',
 'cosine_proximity']
'''

score = model.evaluate(testX, testY, batch_size=batchsize)
print "\n"
print "Model tested."
print "Testing metrics"
for i in range(0,len(modelmetrics)):
	print modelmetrics[i]+": "+str(score[i+1])

predictedax = []
predicteday = []
predictedaz = []
predictedgx = []
predictedgy = []
predictedgz = []
for i in range(len(testX)):
    curr_frame=testX[i]
    predictionResult=model.predict(curr_frame[np.newaxis,:,:])[0,]
    predictedax.append(predictionResult[0])
    predicteday.append(predictionResult[1])
    predictedaz.append(predictionResult[2])
    predictedgx.append(predictionResult[3])
    predictedgy.append(predictionResult[4])
    predictedgz.append(predictionResult[5])

print "\n"
print "Doing one step predictions"
predicteday=np.array(predicteday)
predictedax=np.array(predictedax)
predictedaz=np.array(predictedaz)
predictedgy=np.array(predictedgy)
predictedgx=np.array(predictedgx)
predictedgz=np.array(predictedgz)
prediction=np.column_stack((predictedax,predicteday))
prediction=np.column_stack((prediction,predictedaz))
prediction=np.column_stack((prediction,predictedgx))
prediction=np.column_stack((prediction,predictedgy))
prediction=np.column_stack((prediction,predictedgz))
predictedUnpreprocessed =  allScaler.inverse_transform(prediction)
predictedtestY=allScaler.inverse_transform(testY)
exportcsv= np.column_stack((predictedUnpreprocessed,predictedtestY))
xaxis=np.arange(len(predictedUnpreprocessed))
#xaxis=np.column_stack((xaxis,xaxis%24))
final=np.column_stack((xaxis,exportcsv))
np.savetxt('predictionResult.csv', final, delimiter=',',fmt="%0f")#, header=nodeid+"Date,Hour,Predicted_DL,Predicted_UL,Predicted_connmax,Actual_DL,Actual_UL,Actual_connmax")
print "One step predictions outputted"
dfax=pd.DataFrame({'x': final[:,0], 'y1': final[:,1], 'y2': final[:,7] })
pyplot.plot( 'x', 'y2', data=dfax, marker='', color='skyblue', linewidth=2, label='Actual ax')
pyplot.plot( 'x', 'y1', data=dfax, marker='', color='olive', linewidth=2, label='Predicted ax')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("ax")
pyplot.show()

dfay=pd.DataFrame({'x': final[:,0], 'y1': final[:,2], 'y2': final[:,8] })
pyplot.plot( 'x', 'y2', data=dfay, marker='', color='skyblue', linewidth=2, label='Actual ay')
pyplot.plot( 'x', 'y1', data=dfay, marker='', color='olive', linewidth=2, label='Predicted ay')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("ay")
pyplot.show()

dfaz=pd.DataFrame({'x': final[:,0], 'y1': final[:,3], 'y2': final[:,9] })
pyplot.plot( 'x', 'y2', data=dfaz, marker='', color='skyblue', linewidth=2, label='Actual az')
pyplot.plot( 'x', 'y1', data=dfaz, marker='', color='olive', linewidth=2, label='Predicted az')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("az")
pyplot.show()


dfgx=pd.DataFrame({'x': final[:,0], 'y1': final[:,4], 'y2': final[:,10] })
pyplot.plot( 'x', 'y2', data=dfgx, marker='', color='skyblue', linewidth=2, label='Actual gx')
pyplot.plot( 'x', 'y1', data=dfgx, marker='', color='olive', linewidth=2, label='Predicted gx')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("gx")
pyplot.show()

dfgy=pd.DataFrame({'x': final[:,0], 'y1': final[:,5], 'y2': final[:,11] })
pyplot.plot( 'x', 'y2', data=dfgy, marker='', color='skyblue', linewidth=2, label='Actual gy')
pyplot.plot( 'x', 'y1', data=dfgy, marker='', color='olive', linewidth=2, label='Predicted gy')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("gy")
pyplot.show()

dfgz=pd.DataFrame({'x': final[:,0], 'y1': final[:,6], 'y2': final[:,12] })
pyplot.plot( 'x', 'y2', data=dfgz, marker='', color='skyblue', linewidth=2, label='Actual gz')
pyplot.plot( 'x', 'y1', data=dfgz, marker='', color='olive', linewidth=2, label='Predicted gz')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("gz")
pyplot.show()
# Out:
# Using TensorFlow backend.
# Dataset loaded.
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:91: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:91: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(units=24, return_sequences=True, input_shape=(None, 1))`
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel_launcher.py:103: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=6)`
# Model compiled.
# Epoch 1/300
#  - 6s - loss: 0.2323 - mean_squared_error: 0.2323 - mean_absolute_error: 0.4542
# Epoch 2/300
#  - 4s - loss: 0.0940 - mean_squared_error: 0.0940 - mean_absolute_error: 0.2465
# Epoch 3/300
#  - 4s - loss: 0.0706 - mean_squared_error: 0.0706 - mean_absolute_error: 0.1949
# Epoch 4/300
#  - 4s - loss: 0.0682 - mean_squared_error: 0.0682 - mean_absolute_error: 0.1901
# Epoch 5/300
#  - 4s - loss: 0.0693 - mean_squared_error: 0.0693 - mean_absolute_error: 0.1918
# Epoch 6/300
#  - 3s - loss: 0.0672 - mean_squared_error: 0.0672 - mean_absolute_error: 0.1874
# Epoch 7/300
#  - 3s - loss: 0.0667 - mean_squared_error: 0.0667 - mean_absolute_error: 0.1858
# Epoch 8/300
#  - 4s - loss: 0.0696 - mean_squared_error: 0.0696 - mean_absolute_error: 0.1934
# Epoch 9/300
#  - 4s - loss: 0.0668 - mean_squared_error: 0.0668 - mean_absolute_error: 0.1857
# Epoch 10/300
#  - 3s - loss: 0.0678 - mean_squared_error: 0.0678 - mean_absolute_error: 0.1888
# Epoch 11/300
#  - 3s - loss: 0.0669 - mean_squared_error: 0.0669 - mean_absolute_error: 0.1866
# Epoch 12/300
#  - 3s - loss: 0.0660 - mean_squared_error: 0.0660 - mean_absolute_error: 0.1839
# Epoch 13/300
#  - 5s - loss: 0.0678 - mean_squared_error: 0.0678 - mean_absolute_error: 0.1891
# Epoch 14/300
#  - 3s - loss: 0.0657 - mean_squared_error: 0.0657 - mean_absolute_error: 0.1833
# Epoch 15/300
#  - 4s - loss: 0.0658 - mean_squared_error: 0.0658 - mean_absolute_error: 0.1824
# Epoch 16/300
#  - 4s - loss: 0.0661 - mean_squared_error: 0.0661 - mean_absolute_error: 0.1846
# Epoch 17/300
#  - 4s - loss: 0.0645 - mean_squared_error: 0.0645 - mean_absolute_error: 0.1799
# Epoch 18/300
#  - 4s - loss: 0.0658 - mean_squared_error: 0.0658 - mean_absolute_error: 0.1832
# Epoch 19/300
#  - 5s - loss: 0.0662 - mean_squared_error: 0.0662 - mean_absolute_error: 0.1846
# Epoch 20/300
#  - 4s - loss: 0.0641 - mean_squared_error: 0.0641 - mean_absolute_error: 0.1788
# Epoch 21/300
#  - 4s - loss: 0.0652 - mean_squared_error: 0.0652 - mean_absolute_error: 0.1816
# Epoch 22/300
#  - 4s - loss: 0.0648 - mean_squared_error: 0.0648 - mean_absolute_error: 0.1806
# Epoch 23/300
#  - 4s - loss: 0.0642 - mean_squared_error: 0.0642 - mean_absolute_error: 0.1788
# Epoch 24/300
#  - 6s - loss: 0.0658 - mean_squared_error: 0.0658 - mean_absolute_error: 0.1827
# Epoch 25/300
#  - 6s - loss: 0.0641 - mean_squared_error: 0.0641 - mean_absolute_error: 0.1790
# Epoch 26/300
#  - 6s - loss: 0.0649 - mean_squared_error: 0.0649 - mean_absolute_error: 0.1811
# Epoch 27/300
#  - 6s - loss: 0.0652 - mean_squared_error: 0.0652 - mean_absolute_error: 0.1812
# Epoch 28/300
#  - 5s - loss: 0.0642 - mean_squared_error: 0.0642 - mean_absolute_error: 0.1785
# Epoch 29/300
#  - 5s - loss: 0.0647 - mean_squared_error: 0.0647 - mean_absolute_error: 0.1791
# Epoch 30/300
#  - 5s - loss: 0.0648 - mean_squared_error: 0.0648 - mean_absolute_error: 0.1811
# Epoch 31/300
#  - 5s - loss: 0.0639 - mean_squared_error: 0.0639 - mean_absolute_error: 0.1771
# Epoch 32/300
#  - 4s - loss: 0.0636 - mean_squared_error: 0.0636 - mean_absolute_error: 0.1769
# Epoch 33/300
#  - 4s - loss: 0.0641 - mean_squared_error: 0.0641 - mean_absolute_error: 0.1793
# Epoch 34/300
#  - 4s - loss: 0.0643 - mean_squared_error: 0.0643 - mean_absolute_error: 0.1789
# Epoch 35/300
#  - 3s - loss: 0.0639 - mean_squared_error: 0.0639 - mean_absolute_error: 0.1771
# Epoch 36/300
#  - 4s - loss: 0.0634 - mean_squared_error: 0.0634 - mean_absolute_error: 0.1759
# Epoch 37/300
#  - 4s - loss: 0.0637 - mean_squared_error: 0.0637 - mean_absolute_error: 0.1760
# Epoch 38/300
#  - 4s - loss: 0.0637 - mean_squared_error: 0.0637 - mean_absolute_error: 0.1765
# Epoch 39/300
#  - 4s - loss: 0.0636 - mean_squared_error: 0.0636 - mean_absolute_error: 0.1763
# Epoch 40/300
#  - 3s - loss: 0.0632 - mean_squared_error: 0.0632 - mean_absolute_error: 0.1757
# Epoch 41/300
#  - 4s - loss: 0.0637 - mean_squared_error: 0.0637 - mean_absolute_error: 0.1771
# Epoch 42/300
#  - 3s - loss: 0.0635 - mean_squared_error: 0.0635 - mean_absolute_error: 0.1767
# Epoch 43/300
#  - 3s - loss: 0.0640 - mean_squared_error: 0.0640 - mean_absolute_error: 0.1775
# Epoch 44/300
#  - 3s - loss: 0.0634 - mean_squared_error: 0.0634 - mean_absolute_error: 0.1755
# Epoch 45/300
#  - 5s - loss: 0.0630 - mean_squared_error: 0.0630 - mean_absolute_error: 0.1745
# Epoch 46/300
#  - 3s - loss: 0.0635 - mean_squared_error: 0.0635 - mean_absolute_error: 0.1760
# Epoch 47/300
#  - 3s - loss: 0.0628 - mean_squared_error: 0.0628 - mean_absolute_error: 0.1743
# Epoch 48/300
#  - 4s - loss: 0.0632 - mean_squared_error: 0.0632 - mean_absolute_error: 0.1750
# Epoch 49/300
#  - 3s - loss: 0.0629 - mean_squared_error: 0.0629 - mean_absolute_error: 0.1746
# Epoch 50/300
#  - 4s - loss: 0.0631 - mean_squared_error: 0.0631 - mean_absolute_error: 0.1748
# Epoch 51/300
#  - 3s - loss: 0.0631 - mean_squared_error: 0.0631 - mean_absolute_error: 0.1746
# Epoch 52/300
#  - 3s - loss: 0.0629 - mean_squared_error: 0.0629 - mean_absolute_error: 0.1748
# Epoch 53/300
#  - 3s - loss: 0.0631 - mean_squared_error: 0.0631 - mean_absolute_error: 0.1747
# Epoch 54/300
#  - 3s - loss: 0.0634 - mean_squared_error: 0.0634 - mean_absolute_error: 0.1747
# Epoch 55/300
#  - 4s - loss: 0.0625 - mean_squared_error: 0.0625 - mean_absolute_error: 0.1733
# Epoch 56/300
#  - 4s - loss: 0.0628 - mean_squared_error: 0.0628 - mean_absolute_error: 0.1738
# Epoch 57/300
#  - 4s - loss: 0.0631 - mean_squared_error: 0.0631 - mean_absolute_error: 0.1742
# Epoch 58/300
#  - 5s - loss: 0.0630 - mean_squared_error: 0.0630 - mean_absolute_error: 0.1745
# Epoch 59/300
#  - 5s - loss: 0.0627 - mean_squared_error: 0.0627 - mean_absolute_error: 0.1733
# Epoch 60/300
#  - 4s - loss: 0.0628 - mean_squared_error: 0.0628 - mean_absolute_error: 0.1736
# Epoch 61/300
#  - 4s - loss: 0.0626 - mean_squared_error: 0.0626 - mean_absolute_error: 0.1728
# Epoch 62/300
#  - 4s - loss: 0.0634 - mean_squared_error: 0.0634 - mean_absolute_error: 0.1750
# Epoch 63/300
#  - 3s - loss: 0.0622 - mean_squared_error: 0.0622 - mean_absolute_error: 0.1714
# Epoch 64/300
#  - 4s - loss: 0.0629 - mean_squared_error: 0.0629 - mean_absolute_error: 0.1746
# Epoch 65/300
#  - 3s - loss: 0.0625 - mean_squared_error: 0.0625 - mean_absolute_error: 0.1721
# Epoch 66/300
#  - 3s - loss: 0.0621 - mean_squared_error: 0.0621 - mean_absolute_error: 0.1721
# Epoch 67/300
#  - 6s - loss: 0.0625 - mean_squared_error: 0.0625 - mean_absolute_error: 0.1725
# Epoch 68/300
#  - 5s - loss: 0.0623 - mean_squared_error: 0.0623 - mean_absolute_error: 0.1722
# Epoch 69/300
#  - 4s - loss: 0.0627 - mean_squared_error: 0.0627 - mean_absolute_error: 0.1734
# Epoch 70/300
#  - 4s - loss: 0.0626 - mean_squared_error: 0.0626 - mean_absolute_error: 0.1726
# Epoch 71/300
#  - 4s - loss: 0.0623 - mean_squared_error: 0.0623 - mean_absolute_error: 0.1722
# Epoch 72/300
#  - 3s - loss: 0.0620 - mean_squared_error: 0.0620 - mean_absolute_error: 0.1708
# Epoch 73/300
#  - 3s - loss: 0.0629 - mean_squared_error: 0.0629 - mean_absolute_error: 0.1737
# Epoch 74/300
#  - 4s - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.1707
# Epoch 75/300
#  - 3s - loss: 0.0622 - mean_squared_error: 0.0622 - mean_absolute_error: 0.1714
# Epoch 76/300
#  - 3s - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.1704
# Epoch 77/300
#  - 3s - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.1711
# Epoch 78/300
#  - 3s - loss: 0.0623 - mean_squared_error: 0.0623 - mean_absolute_error: 0.1720
# Epoch 79/300
#  - 3s - loss: 0.0625 - mean_squared_error: 0.0625 - mean_absolute_error: 0.1728
# Epoch 80/300
#  - 3s - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.1709
# Epoch 81/300
#  - 4s - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.1716
# Epoch 82/300
#  - 4s - loss: 0.0618 - mean_squared_error: 0.0618 - mean_absolute_error: 0.1707
# Epoch 83/300
#  - 4s - loss: 0.0622 - mean_squared_error: 0.0622 - mean_absolute_error: 0.1713
# Epoch 84/300
#  - 3s - loss: 0.0617 - mean_squared_error: 0.0617 - mean_absolute_error: 0.1702
# Epoch 85/300
#  - 4s - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.1712
# Epoch 86/300
#  - 4s - loss: 0.0618 - mean_squared_error: 0.0618 - mean_absolute_error: 0.1698
# Epoch 87/300
#  - 4s - loss: 0.0618 - mean_squared_error: 0.0618 - mean_absolute_error: 0.1709
# Epoch 88/300
#  - 4s - loss: 0.0616 - mean_squared_error: 0.0616 - mean_absolute_error: 0.1695
# Epoch 89/300
#  - 4s - loss: 0.0622 - mean_squared_error: 0.0622 - mean_absolute_error: 0.1714
# Epoch 90/300
#  - 4s - loss: 0.0617 - mean_squared_error: 0.0617 - mean_absolute_error: 0.1695
# Epoch 91/300
#  - 3s - loss: 0.0617 - mean_squared_error: 0.0617 - mean_absolute_error: 0.1698
# Epoch 92/300
#  - 3s - loss: 0.0616 - mean_squared_error: 0.0616 - mean_absolute_error: 0.1703
# Epoch 93/300
#  - 4s - loss: 0.0615 - mean_squared_error: 0.0615 - mean_absolute_error: 0.1697
# Epoch 94/300
#  - 3s - loss: 0.0617 - mean_squared_error: 0.0617 - mean_absolute_error: 0.1703
# Epoch 95/300
#  - 3s - loss: 0.0615 - mean_squared_error: 0.0615 - mean_absolute_error: 0.1691
# Epoch 96/300
#  - 3s - loss: 0.0613 - mean_squared_error: 0.0613 - mean_absolute_error: 0.1682
# Epoch 97/300
#  - 3s - loss: 0.0616 - mean_squared_error: 0.0616 - mean_absolute_error: 0.1694
# Epoch 98/300
#  - 3s - loss: 0.0615 - mean_squared_error: 0.0615 - mean_absolute_error: 0.1699
# Epoch 99/300
#  - 4s - loss: 0.0614 - mean_squared_error: 0.0614 - mean_absolute_error: 0.1688
# Epoch 100/300
#  - 4s - loss: 0.0612 - mean_squared_error: 0.0612 - mean_absolute_error: 0.1688
# Epoch 101/300
#  - 3s - loss: 0.0612 - mean_squared_error: 0.0612 - mean_absolute_error: 0.1679
# Epoch 102/300
#  - 4s - loss: 0.0616 - mean_squared_error: 0.0616 - mean_absolute_error: 0.1696
# Epoch 103/300
#  - 4s - loss: 0.0611 - mean_squared_error: 0.0611 - mean_absolute_error: 0.1681
# Epoch 104/300
#  - 4s - loss: 0.0613 - mean_squared_error: 0.0613 - mean_absolute_error: 0.1687
# Epoch 105/300
#  - 4s - loss: 0.0608 - mean_squared_error: 0.0608 - mean_absolute_error: 0.1673
# Epoch 106/300
#  - 4s - loss: 0.0606 - mean_squared_error: 0.0606 - mean_absolute_error: 0.1665
# Epoch 107/300
#  - 3s - loss: 0.0608 - mean_squared_error: 0.0608 - mean_absolute_error: 0.1671
# Epoch 108/300
#  - 4s - loss: 0.0600 - mean_squared_error: 0.0600 - mean_absolute_error: 0.1651
# Epoch 109/300
#  - 4s - loss: 0.0601 - mean_squared_error: 0.0601 - mean_absolute_error: 0.1653
# Epoch 110/300
#  - 4s - loss: 0.0592 - mean_squared_error: 0.0592 - mean_absolute_error: 0.1629
# Epoch 111/300
#  - 3s - loss: 0.0600 - mean_squared_error: 0.0600 - mean_absolute_error: 0.1657
# Epoch 112/300
#  - 3s - loss: 0.0596 - mean_squared_error: 0.0596 - mean_absolute_error: 0.1646
# Epoch 113/300
#  - 3s - loss: 0.0598 - mean_squared_error: 0.0598 - mean_absolute_error: 0.1644
# Epoch 114/300
#  - 3s - loss: 0.0592 - mean_squared_error: 0.0592 - mean_absolute_error: 0.1635
# Epoch 115/300
#  - 3s - loss: 0.0594 - mean_squared_error: 0.0594 - mean_absolute_error: 0.1633
# Epoch 116/300
#  - 3s - loss: 0.0591 - mean_squared_error: 0.0591 - mean_absolute_error: 0.1634
# Epoch 117/300
#  - 3s - loss: 0.0588 - mean_squared_error: 0.0588 - mean_absolute_error: 0.1625
# Epoch 118/300
#  - 5s - loss: 0.0587 - mean_squared_error: 0.0587 - mean_absolute_error: 0.1614
# Epoch 119/300
#  - 4s - loss: 0.0588 - mean_squared_error: 0.0588 - mean_absolute_error: 0.1620
# Epoch 120/300
#  - 3s - loss: 0.0589 - mean_squared_error: 0.0589 - mean_absolute_error: 0.1623
# Epoch 121/300
#  - 4s - loss: 0.0583 - mean_squared_error: 0.0583 - mean_absolute_error: 0.1602
# Epoch 122/300
#  - 4s - loss: 0.0597 - mean_squared_error: 0.0597 - mean_absolute_error: 0.1640
# Epoch 123/300
#  - 4s - loss: 0.0582 - mean_squared_error: 0.0582 - mean_absolute_error: 0.1597
# Epoch 124/300
#  - 4s - loss: 0.0588 - mean_squared_error: 0.0588 - mean_absolute_error: 0.1621
# Epoch 125/300
#  - 4s - loss: 0.0583 - mean_squared_error: 0.0583 - mean_absolute_error: 0.1608
# Epoch 126/300
#  - 3s - loss: 0.0583 - mean_squared_error: 0.0583 - mean_absolute_error: 0.1597
# Epoch 127/300
#  - 4s - loss: 0.0583 - mean_squared_error: 0.0583 - mean_absolute_error: 0.1603
# Epoch 128/300
#  - 3s - loss: 0.0584 - mean_squared_error: 0.0584 - mean_absolute_error: 0.1606
# Epoch 129/300
#  - 4s - loss: 0.0588 - mean_squared_error: 0.0588 - mean_absolute_error: 0.1617
# Epoch 130/300
#  - 3s - loss: 0.0586 - mean_squared_error: 0.0586 - mean_absolute_error: 0.1602
# Epoch 131/300
#  - 3s - loss: 0.0587 - mean_squared_error: 0.0587 - mean_absolute_error: 0.1617
# Epoch 132/300
#  - 3s - loss: 0.0586 - mean_squared_error: 0.0586 - mean_absolute_error: 0.1607
# Epoch 133/300
#  - 3s - loss: 0.0580 - mean_squared_error: 0.0580 - mean_absolute_error: 0.1604
# Epoch 134/300
#  - 3s - loss: 0.0408 - mean_squared_error: 0.0408 - mean_absolute_error: 0.1481
# Epoch 135/300
#  - 3s - loss: 0.0203 - mean_squared_error: 0.0203 - mean_absolute_error: 0.1094
# Epoch 136/300
#  - 4s - loss: 0.0170 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0990
# Epoch 137/300
#  - 6s - loss: 0.0173 - mean_squared_error: 0.0173 - mean_absolute_error: 0.0991
# Epoch 138/300
#  - 4s - loss: 0.0172 - mean_squared_error: 0.0172 - mean_absolute_error: 0.0991
# Epoch 139/300
#  - 4s - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.0983
# Epoch 140/300
#  - 3s - loss: 0.0162 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0959
# Epoch 141/300
#  - 3s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0934
# Epoch 142/300
#  - 4s - loss: 0.0160 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0955
# Epoch 143/300
#  - 5s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0967
# Epoch 144/300
#  - 3s - loss: 0.0161 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0959
# Epoch 145/300
#  - 4s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0926
# Epoch 146/300
#  - 4s - loss: 0.0152 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0942
# Epoch 147/300
#  - 4s - loss: 0.0149 - mean_squared_error: 0.0149 - mean_absolute_error: 0.0913
# Epoch 148/300
#  - 5s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0923
# Epoch 149/300
#  - 5s - loss: 0.0154 - mean_squared_error: 0.0154 - mean_absolute_error: 0.0946
# Epoch 150/300
#  - 4s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0928
# Epoch 151/300
#  - 4s - loss: 0.0150 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0926
# Epoch 152/300
#  - 4s - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0916
# Epoch 153/300
#  - 4s - loss: 0.0162 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0972
# Epoch 154/300
#  - 4s - loss: 0.0141 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0888
# Epoch 155/300
#  - 4s - loss: 0.0141 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0898
# Epoch 156/300
#  - 4s - loss: 0.0146 - mean_squared_error: 0.0146 - mean_absolute_error: 0.0906
# Epoch 157/300
#  - 5s - loss: 0.0145 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0903
# Epoch 158/300
#  - 4s - loss: 0.0140 - mean_squared_error: 0.0140 - mean_absolute_error: 0.0890
# Epoch 159/300
#  - 3s - loss: 0.0148 - mean_squared_error: 0.0148 - mean_absolute_error: 0.0913
# Epoch 160/300
#  - 4s - loss: 0.0144 - mean_squared_error: 0.0144 - mean_absolute_error: 0.0905
# Epoch 161/300
#  - 4s - loss: 0.0141 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0892
# Epoch 162/300
#  - 5s - loss: 0.0146 - mean_squared_error: 0.0146 - mean_absolute_error: 0.0917
# Epoch 163/300
#  - 4s - loss: 0.0139 - mean_squared_error: 0.0139 - mean_absolute_error: 0.0888
# Epoch 164/300
#  - 5s - loss: 0.0142 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0888
# Epoch 165/300
#  - 5s - loss: 0.0140 - mean_squared_error: 0.0140 - mean_absolute_error: 0.0883
# Epoch 166/300
#  - 4s - loss: 0.0142 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0895
# Epoch 167/300
#  - 4s - loss: 0.0132 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0863
# Epoch 168/300
#  - 4s - loss: 0.0133 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0852
# Epoch 169/300
#  - 3s - loss: 0.0133 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0860
# Epoch 170/300
#  - 4s - loss: 0.0140 - mean_squared_error: 0.0140 - mean_absolute_error: 0.0885
# Epoch 171/300
#  - 3s - loss: 0.0133 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0864
# Epoch 172/300
#  - 4s - loss: 0.0142 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0894
# Epoch 173/300
#  - 4s - loss: 0.0136 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0872
# Epoch 174/300
#  - 3s - loss: 0.0131 - mean_squared_error: 0.0131 - mean_absolute_error: 0.0857
# Epoch 175/300
#  - 4s - loss: 0.0138 - mean_squared_error: 0.0138 - mean_absolute_error: 0.0879
# Epoch 176/300
#  - 3s - loss: 0.0133 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0862
# Epoch 177/300
#  - 4s - loss: 0.0127 - mean_squared_error: 0.0127 - mean_absolute_error: 0.0842
# Epoch 178/300
#  - 4s - loss: 0.0137 - mean_squared_error: 0.0137 - mean_absolute_error: 0.0874
# Epoch 179/300
#  - 4s - loss: 0.0132 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0858
# Epoch 180/300
#  - 3s - loss: 0.0131 - mean_squared_error: 0.0131 - mean_absolute_error: 0.0853
# Epoch 181/300
#  - 3s - loss: 0.0132 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0862
# Epoch 182/300
#  - 4s - loss: 0.0133 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0862
# Epoch 183/300
#  - 4s - loss: 0.0125 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0832
# Epoch 184/300
#  - 4s - loss: 0.0126 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0832
# Epoch 185/300
#  - 4s - loss: 0.0126 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0831
# Epoch 186/300
#  - 4s - loss: 0.0127 - mean_squared_error: 0.0127 - mean_absolute_error: 0.0838
# Epoch 187/300
#  - 4s - loss: 0.0134 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0859
# Epoch 188/300
#  - 3s - loss: 0.0130 - mean_squared_error: 0.0130 - mean_absolute_error: 0.0851
# Epoch 189/300
#  - 3s - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0816
# Epoch 190/300
#  - 4s - loss: 0.0127 - mean_squared_error: 0.0127 - mean_absolute_error: 0.0831
# Epoch 191/300
#  - 4s - loss: 0.0123 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0825
# Epoch 192/300
#  - 3s - loss: 0.0125 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0825
# Epoch 193/300
#  - 3s - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0822
# Epoch 194/300
#  - 3s - loss: 0.0125 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0833
# Epoch 195/300
#  - 3s - loss: 0.0126 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0841
# Epoch 196/300
#  - 4s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0807
# Epoch 197/300
#  - 4s - loss: 0.0123 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0816
# Epoch 198/300
#  - 3s - loss: 0.0124 - mean_squared_error: 0.0124 - mean_absolute_error: 0.0824
# Epoch 199/300
#  - 3s - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0813
# Epoch 200/300
#  - 3s - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0804
# Epoch 201/300
#  - 3s - loss: 0.0121 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0816
# Epoch 202/300
#  - 4s - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0816
# Epoch 203/300
#  - 4s - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0801
# Epoch 204/300
#  - 6s - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0815
# Epoch 205/300
#  - 5s - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0818
# Epoch 206/300
#  - 4s - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0802
# Epoch 207/300
#  - 4s - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0813
# Epoch 208/300
#  - 4s - loss: 0.0123 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0826
# Epoch 209/300
#  - 4s - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0802
# Epoch 210/300
#  - 4s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0792
# Epoch 211/300
#  - 6s - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0817
# Epoch 212/300
#  - 5s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0794
# Epoch 213/300
#  - 4s - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0803
# Epoch 214/300
#  - 4s - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0806
# Epoch 215/300
#  - 4s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0796
# Epoch 216/300
#  - 4s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0795
# Epoch 217/300
#  - 3s - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0798
# Epoch 218/300
#  - 4s - loss: 0.0123 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0817
# Epoch 219/300
#  - 4s - loss: 0.0111 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0773
# Epoch 220/300
#  - 4s - loss: 0.0113 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0781
# Epoch 221/300
#  - 3s - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0795
# Epoch 222/300
#  - 5s - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0782
# Epoch 223/300
#  - 4s - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0791
# Epoch 224/300
#  - 4s - loss: 0.0115 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0777
# Epoch 225/300
#  - 4s - loss: 0.0109 - mean_squared_error: 0.0109 - mean_absolute_error: 0.0767
# Epoch 226/300
#  - 4s - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0800
# Epoch 227/300
#  - 4s - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0790
# Epoch 228/300
#  - 3s - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0796
# Epoch 229/300
#  - 3s - loss: 0.0115 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0787
# Epoch 230/300
#  - 4s - loss: 0.0109 - mean_squared_error: 0.0109 - mean_absolute_error: 0.0766
# Epoch 231/300
#  - 4s - loss: 0.0111 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0770
# Epoch 232/300
#  - 4s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0800
# Epoch 233/300
#  - 4s - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0787
# Epoch 234/300
#  - 3s - loss: 0.0113 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0784
# Epoch 235/300
#  - 4s - loss: 0.0112 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0775
# Epoch 236/300
#  - 4s - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0785
# Epoch 237/300
#  - 3s - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0782
# Epoch 238/300
#  - 3s - loss: 0.0115 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0783
# Epoch 239/300
#  - 4s - loss: 0.0109 - mean_squared_error: 0.0109 - mean_absolute_error: 0.0764
# Epoch 240/300
#  - 4s - loss: 0.0112 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0782
# Epoch 241/300
#  - 5s - loss: 0.0113 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0782
# Epoch 242/300
#  - 4s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0795
# Epoch 243/300
#  - 5s - loss: 0.0106 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0751
# Epoch 244/300
#  - 5s - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0791
# Epoch 245/300
#  - 3s - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0751
# Epoch 246/300
#  - 3s - loss: 0.0113 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0783
# Epoch 247/300
#  - 4s - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0793
# Epoch 248/300
#  - 3s - loss: 0.0108 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0764
# Epoch 249/300
#  - 3s - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0772
# Epoch 250/300
#  - 3s - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0767
# Epoch 251/300
#  - 4s - loss: 0.0108 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0764
# Epoch 252/300
#  - 4s - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0772
# Epoch 253/300
#  - 6s - loss: 0.0111 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0775
# Epoch 254/300
#  - 6s - loss: 0.0108 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0758
# Epoch 255/300
#  - 4s - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0793
# Epoch 256/300
#  - 4s - loss: 0.0104 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0743
# Epoch 257/300
#  - 4s - loss: 0.0112 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0777
# Epoch 258/300
#  - 4s - loss: 0.0112 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0770
# Epoch 259/300
#  - 3s - loss: 0.0108 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0766
# Epoch 260/300
#  - 4s - loss: 0.0105 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0752
# Epoch 261/300
#  - 3s - loss: 0.0111 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0776
# Epoch 262/300
#  - 4s - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0755
# Epoch 263/300
#  - 4s - loss: 0.0109 - mean_squared_error: 0.0109 - mean_absolute_error: 0.0768
# Epoch 264/300
#  - 4s - loss: 0.0108 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0763
# Epoch 265/300
#  - 3s - loss: 0.0104 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0748
# Epoch 266/300
#  - 4s - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0753
# Epoch 267/300
#  - 4s - loss: 0.0109 - mean_squared_error: 0.0109 - mean_absolute_error: 0.0763
# Epoch 268/300
#  - 4s - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0757
# Epoch 269/300
#  - 4s - loss: 0.0106 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0754
# Epoch 270/300
#  - 4s - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0766
# Epoch 271/300
#  - 4s - loss: 0.0108 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0751
# Epoch 272/300
#  - 5s - loss: 0.0104 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0745
# Epoch 273/300
#  - 5s - loss: 0.0109 - mean_squared_error: 0.0109 - mean_absolute_error: 0.0757
# Epoch 274/300
#  - 5s - loss: 0.0102 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0739
# Epoch 275/300
#  - 4s - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0756
# Epoch 276/300
#  - 4s - loss: 0.0110 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0766
# Epoch 277/300
#  - 4s - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0759
# Epoch 278/300
#  - 4s - loss: 0.0105 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0750
# Epoch 279/300
#  - 4s - loss: 0.0102 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0738
# Epoch 280/300
#  - 4s - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0757
# Epoch 281/300
#  - 4s - loss: 0.0106 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0754
# Epoch 282/300
#  - 4s - loss: 0.0105 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0754
# Epoch 283/300
#  - 4s - loss: 0.0106 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0749
# Epoch 284/300
#  - 3s - loss: 0.0106 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0748
# Epoch 285/300
#  - 4s - loss: 0.0104 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0741
# Epoch 286/300
#  - 4s - loss: 0.0108 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0756
# Epoch 287/300
#  - 3s - loss: 0.0101 - mean_squared_error: 0.0101 - mean_absolute_error: 0.0728
# Epoch 288/300
#  - 3s - loss: 0.0106 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0750
# Epoch 289/300
#  - 3s - loss: 0.0107 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0754
# Epoch 290/300
#  - 3s - loss: 0.0104 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0745
# Epoch 291/300
#  - 3s - loss: 0.0105 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0748
# Epoch 292/300
#  - 3s - loss: 0.0102 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0736
# Epoch 293/300
#  - 3s - loss: 0.0104 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0747
# Epoch 294/300
#  - 3s - loss: 0.0105 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0744
# Epoch 295/300
#  - 3s - loss: 0.0103 - mean_squared_error: 0.0103 - mean_absolute_error: 0.0736
# Epoch 296/300
#  - 4s - loss: 0.0102 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0737
# Epoch 297/300
#  - 4s - loss: 0.0103 - mean_squared_error: 0.0103 - mean_absolute_error: 0.0741
# Epoch 298/300
#  - 3s - loss: 0.0102 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0734
# Epoch 299/300
#  - 4s - loss: 0.0105 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0749
# Epoch 300/300
#  - 4s - loss: 0.0102 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0734
# Model trained.
# ----------------------------------------------------------------------------------------------
# mean_squared_error
# mean_absolute_error
# ----------------------------------------------------------------------------------------------
#
#
# Training metrics
# mean_squared_error: 0.0102221267937
# mean_absolute_error: 0.0734236660881
#
#
# 233/233 [==============================] - 0s 1ms/step
#
#
# Model tested.
# Testing metrics
# mean_squared_error: 0.0396263764236
# mean_absolute_error: 0.142330643061
#
#
# Doing one step predictions
# One step predictions outputted
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/pyplot.py:3154: RuntimeWarning: Second argument is ambiguous: could be a color spec but is in data. Using as data.
# Either rename the entry in data or use three arguments to plot.
#   ret = ax.plot(*args, **kwargs)

# %%
dfax=pd.DataFrame({'x': final[datastart:datacutoff,0], 'y1': final[datastart:datacutoff,1], 'y2': final[datastart:datacutoff,7] })
pyplot.plot( 'x', 'y2', data=dfax, marker='', color='skyblue', linewidth=2, label='Actual Ax')
pyplot.plot( 'x', 'y1', data=dfax, marker='', color='olive', linewidth=2, label='Predicted Ax')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("Ax")
pyplot.savefig("Ax.png")
pyplot.show()

dfay=pd.DataFrame({'x': final[datastart:datacutoff,0], 'y1': final[datastart:datacutoff,2], 'y2': final[datastart:datacutoff,8] })
pyplot.plot( 'x', 'y2', data=dfay, marker='', color='skyblue', linewidth=2, label='Actual Ay')
pyplot.plot( 'x', 'y1', data=dfay, marker='', color='olive', linewidth=2, label='Predicted Ay')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("Ay")
pyplot.savefig("Ay.png")
pyplot.show()

dfaz=pd.DataFrame({'x': final[datastart:datacutoff,0], 'y1': final[datastart:datacutoff,3], 'y2': final[datastart:datacutoff,9] })
pyplot.plot( 'x', 'y2', data=dfaz, marker='', color='skyblue', linewidth=2, label='Actual Az')
pyplot.plot( 'x', 'y1', data=dfaz, marker='', color='olive', linewidth=2, label='Predicted Az')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("Az")
pyplot.savefig("Az.png")
pyplot.show()

dfgx=pd.DataFrame({'x': final[datastart:datacutoff,0], 'y1': final[datastart:datacutoff,4], 'y2': final[datastart:datacutoff,10] })
pyplot.plot( 'x', 'y2', data=dfgx, marker='', color='skyblue', linewidth=2, label='Actual Gx')
pyplot.plot( 'x', 'y1', data=dfgx, marker='', color='olive', linewidth=2, label='Predicted Gx')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("Gx")
pyplot.savefig("Gx.png")
pyplot.show()

dfgy=pd.DataFrame({'x': final[datastart:datacutoff,0], 'y1': final[datastart:datacutoff,5], 'y2': final[datastart:datacutoff,11] })
pyplot.plot( 'x', 'y2', data=dfgy, marker='', color='skyblue', linewidth=2, label='Actual Gy')
pyplot.plot( 'x', 'y1', data=dfgy, marker='', color='olive', linewidth=2, label='Predicted Gy')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("Gy")
pyplot.savefig("Gy.png")
pyplot.show()

dfgz=pd.DataFrame({'x': final[datastart:datacutoff,0], 'y1': final[datastart:datacutoff,6], 'y2': final[datastart:datacutoff,12] })
pyplot.plot( 'x', 'y2', data=dfgz, marker='', color='skyblue', linewidth=2, label='Actual Gz')
pyplot.plot( 'x', 'y1', data=dfgz, marker='', color='olive', linewidth=2, label='Predicted Gz')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.legend()
pyplot.title("Gz")
pyplot.savefig("Gz.png")
pyplot.show()

datacutoff=125
datastart=40

dforig=pd.DataFrame({'x': final[datastart:datacutoff,0], 'y1': final[datastart:datacutoff,7], 'y2': final[datastart:datacutoff,8], 'y3': final[datastart:datacutoff,9], 'y4': final[datastart:datacutoff,10] , 'y5': final[datastart:datacutoff,11], 'y6': final[datastart:datacutoff,12]})
pyplot.plot( 'x', 'y2', data=dforig, marker='', color='skyblue', linewidth=2, label='Ay')
pyplot.plot( 'x', 'y1', data=dforig, marker='', color='olive', linewidth=2, label='Ax')
pyplot.plot( 'x', 'y3', data=dforig, marker='', color='r', linewidth=2, label='Az')
pyplot.plot( 'x', 'y4', data=dforig, marker='', color='c', linewidth=2, label='Gx')
pyplot.plot( 'x', 'y5', data=dforig, marker='', color='m', linewidth=2, label='Gy')
pyplot.plot( 'x', 'y6', data=dforig, marker='', color='y', linewidth=2, label='Gz')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.title("Original output")
pyplot.legend()
pyplot.savefig("origoutput.png")
pyplot.show()

dfpredict=pd.DataFrame({'x': final[datastart:datacutoff,0], 'y1': final[datastart:datacutoff,1], 'y2': final[datastart:datacutoff,2], 'y3': final[datastart:datacutoff,3], 'y4': final[datastart:datacutoff,4] , 'y5': final[datastart:datacutoff,5], 'y6': final[datastart:datacutoff,6]})
pyplot.plot( 'x', 'y2', data=dfpredict, marker='', color='skyblue', linewidth=2, label='Ay')
pyplot.plot( 'x', 'y1', data=dfpredict, marker='', color='olive', linewidth=2, label='Ax')
pyplot.plot( 'x', 'y3', data=dfpredict, marker='', color='r', linewidth=2, label='Az')
pyplot.plot( 'x', 'y4', data=dfpredict, marker='', color='c', linewidth=2, label='Gx')
pyplot.plot( 'x', 'y5', data=dfpredict, marker='', color='m', linewidth=2, label='Gy')
pyplot.plot( 'x', 'y6', data=dfpredict, marker='', color='y', linewidth=2, label='Gz')
#plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
pyplot.title("Predicted output")
pyplot.legend()
pyplot.savefig("predictedoutput.png")
pyplot.show()
